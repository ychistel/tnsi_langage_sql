-- %%
SELECT * FROM Produit;
-- Out:
-- idProduit	NomProduit	CodeProduit	Stock	Prix
-- 1	gel hydroalcoolique 100ml	12x24F	12	3.2
-- 2	masque FFP2 x100	21s53R	17	10.5
-- 3	visière de protection	97D74S	10	9.5
-- 4	désinfectant industriel 10L	10F36A	15	23.25
